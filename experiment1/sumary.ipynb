# %%
import csv
import math

import numpy as np
import os

target_data = [[] for i in range(18)]
X_train = []
Y_train = []

# %%
def read_csv() -> None:
    with open('../data1/train.csv', 'r', encoding='gb18030') as target_csv:
        target_reader = csv.reader(target_csv)
        target_reader.__next__()
        count = 0
        for row in target_reader:
            for i in range(3, 27):
                if row[i] == "NR":
                    target_data[count % 18].append(float(0))
                else:
                    target_data[count % 18].append(float(row[i]))
            count += 1

# %%
read_csv()
print(np.array(target_data).shape)
X_train = []
Y_train = []
for month in range(12):
    for group in range(471):
        X_train.append([])
        for attribute in range(18):
            for hour in range(9):
                X_train[month * 471 + group].append(target_data[attribute][month * 480 + group + hour])
        Y_train.append(target_data[9][month * 480 + group + 9])
X_train = np.array(X_train)
Y_train = np.array(Y_train)
print(np.array(X_train).shape)
# Out:
# (18, 5760)
# (5652, 162)

# %%
iteration = 5000
weights = np.ones(18 * 9)
learning_rate = 0.05
gra_2_sum = np.ones(18 * 9)
for i in range(iteration):
    gradient = np.zeros(18 * 9)
    variance = 0
    for j in range(len(X_train)):
        loss = np.dot(weights, X_train[j]) - Y_train[j]
        variance += loss ** 2
        gradient = 2 * np.dot(X_train[j].T, loss)
        gra_2_sum += gradient ** 2
        ada = np.sqrt(gra_2_sum + 1e-8)
        weights -= learning_rate * gradient / ada
    if i % 50 == 0:
        cost = variance / len(X_train)
        cost_a = math.sqrt(cost)
        print(i, " times ", " variance: ", cost, " standard deviation: ", cost_a)
np.save('model.npy', 'w')
# Out:
# 0  times   variance:  145669.76334196483  standard deviation:  381.6670844361154
# 50  times   variance:  47.124902372719774  standard deviation:  6.864757998117615
# 100  times   variance:  40.77009274221752  standard deviation:  6.385146258482848
# 150  times   variance:  38.14205879763473  standard deviation:  6.1759257441807645
# 200  times   variance:  36.70564790458554  standard deviation:  6.058518622946169
# 250  times   variance:  35.7974695640642  standard deviation:  5.983098659061557
# 300  times   variance:  35.16829898796785  standard deviation:  5.93028658565232
# 350  times   variance:  34.70498979017459  standard deviation:  5.891094108073184
# 400  times   variance:  34.34909636223048  standard deviation:  5.860810213804102
# 450  times   variance:  34.06740097383143  standard deviation:  5.836728619169426
# 500  times   variance:  33.839559388320176  standard deviation:  5.8171779574223255
# 550  times   variance:  33.65232538366892  standard deviation:  5.801062435767169
# 600  times   variance:  33.49662041094869  standard deviation:  5.787626492004186
# 650  times   variance:  33.36594938008539  standard deviation:  5.776326633777334
# 700  times   variance:  33.255497967506116  standard deviation:  5.766758011873406
# 750  times   variance:  33.16159370685628  standard deviation:  5.758610397210101
# 800  times   variance:  33.08137006521259  standard deviation:  5.751640641174706
# 850  times   variance:  33.012548401632856  standard deviation:  5.74565474090054
# 900  times   variance:  32.95329102214738  standard deviation:  5.740495712231426
# 950  times   variance:  32.902098703638  standard deviation:  5.736035103068844
    target_reader = csv.reader(target_csv)
    # target_reader.__next__()
    count = 0
    for row in target_reader:
        for i in range(2, 11):
            if row[i] == "NR":
                target_data[count % 18].append(float(0))
                X_test.append(float(0))
            else:
                target_data[count % 18].append(float(row[i]))
                X_test.append(float(row[i]))
        count += 1
        # if count % 18 == 0:
        #     pre_result = np.dot(weights, X_test)
        #     print(pre_result)

print(np.array(target_data).shape)
# Out:
# (18, 2160)

# %%
X_test = [ [] for i in range(240)]
for group in range(240):
    for attribute in range(18):
        for hour in range(9):
            X_test[group].append(target_data[attribute][group * 8 + hour ])
print(np.array(X_test).shape)
# Out:
# (240, 162)

# %%
pre_list = []
for i in range(len(X_test)):
    pre_result = np.dot(weights, X_test[i])
    print(pre_result)
    pre_list.append(pre_result)
# Out:
# 6.112537654860237
# 15.007990476347613
# 43.05464774895175
# 1.5943264086102964
# 7.8053420700756595
# 27.460203617224458
# 15.469668275896144
# 48.66285859271363
# 11.236876042834671
# 16.270564824010062
# 55.322477528869385
# 25.34290744015777
# 6.389119781710711
# 13.243091021297102
# 42.27457139298097
# 31.612252969897956
# 9.005049275328536
# 31.1283442957029
# 31.85538618630725
# 67.49071529811266
# 0.11070799550755452
# 8.81056396693386
# 33.944103797122885
# 54.17718403929795
# 27.277945339400333
# 5.009670031538556
# 23.132960422406835
# 14.132763019360205
# 34.83822868137223
# 8.547145097520659
# 65.28933651472153
# 15.178666860826281
# 53.065900819470116
# 52.09118147020914
# 32.5631029556949
# 14.266037056362679
# 2.3625455209746145
# 42.55096520541442
# 40.30102147546627
# 36.733721200244744
# 31.86211161159659
# 37.14296503252239
# 29.953525808625628
# 56.559345926725044
# 7.371766981056386
# 7.572571010644121
# 41.830292092001514
# 43.75833553452554
# 33.38498453093086
# 15.238788787925039
# 30.723994925137447
# 24.198897670642197
# 5.486341680246319
# 19.16977995813993
# 25.640102464781894
# 25.762351257091698
# 39.99083532123345
# 6.037474513029708
# 45.04439571323098
# 37.70495666880854
# 18.774985078340272
# 74.32773073210998
# 12.467404399368391
# 31.99120525769646
# 30.028621711373095
# 60.88763756111891
# 29.849539475128832
# 9.05667321152685
# 58.14512023250973
# 13.155816757991156
# 42.289304023043975
# 23.350875531573887
# 13.124007927757432
# 18.103255162851312
# 36.08394507470825
# -3.722151744532179
# 45.891595879401926
# 33.845927657509
# 8.895659812350644
# 30.42774992048206
# 50.59212448384298
# 59.305739065260575
# 1.5214051361835912
# 6.031490258379553
# 11.840226462806687
# 33.96795531048985
# 30.831053779769565
# 43.88960449695876
# 34.135615955918325
# 28.440812001616347
# 23.05858361356402
# 39.89779352991989
# 34.73671381808575
# 40.093185873016694
# -6.905419779221723
# 23.101604040893864
# 24.377803736307158
# 39.63896623742356
# 6.3407461498432145
# 22.910811288252493
# 21.023606089680847
